# %%
# !pip install isodate
# Out:
# Collecting isodate
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 1.6 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from isodate) (1.15.0)
# Installing collected packages: isodate
# Successfully installed isodate-0.6.0

# %%
# !pip install isodate
# Out:
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (0.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from isodate) (1.15.0)

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 4.2 MB/s
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)

# %%
from apiclient.discovery import build
import googleapiclient.discovery
import os
import time
import pandas as pd
from dateutil import parser
import numpy as np
from nltk.probability import FreqDist
import re, nltk
import nltk
import string
import isodate
from nltk import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
factory = StopWordRemoverFactory()
stopwords = factory.get_stop_words()

os.environ["TZ"]="Asia/Jakarta"
time.tzset()




def preprocessing(line):
    emoji_pattern = re.compile("["
        	u"\U0001F600-\U0001F64F"  # emoticons
        	u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        	u"\U0001F680-\U0001F6FF"  # transport & map symbols
        	u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)
    line=emoji_pattern.sub(r'', line) # no emoji
    line = line.upper()
    line = re.sub(r"[{}]".format(string.punctuation), " ", line)
    for stop_word in stopwords:
        line = line.replace(stop_word,' ')
        line =  re.sub(r'\b[0-9(.,)+]*\b', '', line)
    print(line)
    return line



api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyAJft_f_YmksUwI6pi6z_8Hval8tt7pFKo" #ini Youtube API Key Najla

youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey = DEVELOPER_KEY)

#masukkan channel id/link channel youtube
channellink = "UC0WgFW8uvw8yLPOsDZ_82dw"

# get Uploads playlist id
def get_channel_videos(channel_id):
    
    res = youtube.channels().list(id=channel_id, 
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos = []
    next_page_token = None
    
    while 1:
        res = youtube.playlistItems().list(playlistId=playlist_id, 
                                           part='snippet', 
                                           maxResults=50,
                                           pageToken=next_page_token).execute()
        videos += res['items']
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None:
            break
    
    return videos




#mendapatkan link video dari channel yakni video id

data=[]
videos = get_channel_videos(channellink)


for video in videos:
    title=video['snippet']['title']
    desc=video['snippet']['description']
    idv=video['snippet']['resourceId']['videoId']
    res = youtube.videos().list(id=idv, part='contentDetails').execute()
    duration = res['items'][0]['contentDetails']['duration']
    lama=isodate.parse_duration(duration)
    hari=parser.parse(video['snippet']['publishedAt']).strftime("%w")
    jam=parser.parse(video['snippet']['publishedAt']).strftime("%H")
    print(parser.parse(video['snippet']['publishedAt']))
    print(hari)
    hariku=int(hari)
    jami=int(jam)+7
    if jami > 23:
	    jami=jami-24
	    hariku=hariku+1
    if hariku > 6:
	    hariku=0


    if jami < 6 and jami > 21:
	    jami=0
    elif jami > 6 and jami < 15:
	    jami=1
    else:
	    jami=3 
    data.append([hariku,jam,jami,preprocessing(title),lama,preprocessing(desc)])

df = pd.DataFrame(data,columns=['hari', 'jam','jami', 'judul','durasi','desc'])
print(df)
nltk.download('punkt')
fdist = FreqDist(sum(df['judul'].map(word_tokenize), []))
print(fdist.most_common(10))
print(df.groupby('hari').count().max(level=0))
print(df.groupby('jam').count().max(level=0))
print(df.groupby('hari').agg('count'))
print(df.groupby('jami').agg('count'))
print(df['durasi'].mean())
df.to_csv("/yt/data_lorongmisteri.csv",mode='a', encoding='utf-8')
# Out:
# Streaming output truncated to the last 5000 lines.
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  SOSOKKUNTILANAK  SILUMANKERA  SUARAMISTERIUS
# 2019-07-27 05:57:00+00:00
# 6
#    MISTERI POHON TUA UNTUK MAIN AYUNAN KUNTILANAK
#  TEAM MENEMUKAN MAKAM YANG TERDAPAT POHON TUA YANG SANGAT SERAM SEPERTINYA POHON TUA INI TEMPAT AYUNANNYA KUNTILANAK
#
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
#
# SILAHKAN COMMENT  JIKA KALIAN MENDENGAR HAL ANEH ATAUPUN MELIHAT SESUATU PADA SAAT EXPLORE DI SIANG HARI
#
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
#
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  KUNTILANAKAYUNAN  MISTERIPOHONTUA  PENUNGGUPOHON
# 2019-07-27 05:39:19+00:00
# 6
#    KUNTILANAK MERAH KORBAN TERLINDAS KERETA   UJI NYALI
#  DI MAKAM JANTUNGEN INI BIKIN HOST JANTUNGAN SEHINGG UJI NYALI KALI INI HOST DI SERANG BERKALI KALI DENGAN SOSOK KUNTILANAK MERAH YANG KONON KORBAN DARI TERLINDASNYA KERETA
#
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  UJINYALI  KUNTILANAKMERAH  KORBANTERLINDASKERETA
# 2019-07-27 05:11:40+00:00
# 6
#    TEREKAM SOSOK KUNTILANAK MERAH
#  DI MAKAM JANTUNGEN INI BIKIN HOST JANTUNGAN KEMUDIAN TEAM MELIHAT SOSOK KUNTILANAK MERAH YANG KONON BERBAHAYA SEKALI UNTUK MENDEKATINYA  PADA SAAT TEAM MENDEKATINYA TIBA TIBA KAMERAMEN TERJATUH SEPERTI ADA YANG MENARIKNYA DENGAN SANGAT KENCANG
#
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  TRAGEDIKAMERMANTERJATUH  KUNTILANAKMERAH  SUARAMISTERIUS
# 2019-07-27 04:59:48+00:00
# 6
#    MISTERI POHON TUA BERAKAR GANTUNG
#  PADA SAAT SURVEI DI MAKAM HOST MENDENGAR SUARA GERAMAN  TERTAWA KUNTILANAK DAN TERDAPAT POHON TUA MISTERIUS YANG AKARNYA TERGANTUNG
#
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
#
# SILAHKAN COMMENT  JIKA KALIAN MENDENGAR HAL ANEH ATAUPUN MELIHAT SESUATU PADA SAAT EXPLORE DI SIANG HARI
#
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
#
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  SUARAKUNTILANAK  MISTERIPOHONTUABERAKARTERGANTUNG   PENUNGGUPOHON
# 2019-07-24 00:47:29+00:00
# 3
#    MENANTANG JIN SATU LAWAN SATU   UJI NYALI
#  UJI NYALI KALI INI HOST MENANTANG JIN SATU LAWAN SATU DAN TEREKAM SOSOK KUNTILANAK PENUNGGU POHON
#
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  UJINYALI  KUNTILANAK  MENANTANGJINSATULAWANSATU
# 2019-07-26 16:38:15+00:00
# 5
#  GIVEAWAY 100K SUBSCRIBER LORONG MISTERI
# ALHAMDULILLAH TERIMAKASIH KEPADA SELURUH TEMAN TEMANKU  SAUDARAKU  SAHABATKU  KELUARGAKU YANG SELALU MENDUKUNG CHANNEL LORONG MISTERI YANG SAAT INI SUDAH MENCAPAI 100K SUBSCRIBER
#
# DAN KAMI AKAN BAGI BAGI HADIAH UNTUK KALIAN SEMUA
#
# IKUTI PERSYARATANNYA DAN DAPATKAN HADIAHNYA
#
# SYARAT
# SUBSCRIBE KEDUA CHANNEL CHANNEL KAMI
# LORONG MISTERI   GLOUD STUDIOS
# DAN FOLLOW INSTAGRAM
#  LORONGMISTERI    GLOUDSTUDIOS
#
# SYARAT
# SHARE VIDEO YANG SUDAH DI TENTUKAN DENGAN CAPTION TERBAIK DI AKUN SOSMED KALIAN
# KEMUDIAN TAG  TEMAN KALIAN   BUKAN ARTIS
#
# SYARAT
# COMMENT DI VIDEO YANG SUDAH DI TENTUKAN DENGAN NAMA SOSMED KALIAN
# LALU SERTAKAN LINK STATUS SOSMED KALIAN
# DAN KUMPULKAN LIKE SEBANYAK MUNGKIN DI COMMENT TERSEBUT
#
# PEMENANGNYA ADALAH COMMENT DENGAN LIKE PALING TERBANYAK
#
# BATAS WAKTU VOTING LIKE SAMPAI HARI SENIN  AGUSTUS  JAM   WIB DINI HARI
#
# PEMENANG AKAN DI UMUMKAN HARI SENIN  AGUSTUS  JAM   WIB SIANG HARI
#
# SEMOGA BERUNTUNG
#
#  LORONGMISTERI  GIVEAWAY100KSUBSCRIBER  BAGIBAGIHADIAH
# 2019-07-20 17:02:05+00:00
# 6
#    MAK LAMPIR PENUNGGU POHON
#  RUMOR YANG BEREDAR BANYAK SEKALI YANG MENDENGAR SUARA TANGISAN   MAK LAMPIR   PENUNGGU POHON DI MAKAM TERSEBUT
#
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  SUARATANGISAN  MAKLAMPIR  PENUNGGUPOHON
# 2019-07-24 13:51:12+00:00
# 3
#    GADIS NEKAT UJI NYALI DEMI BIAYA SEKOLAH
#  EPISODE EXPLORE KALI INI BERBEDA DARI YANG LAIN KAMI KEDATANGAN SEORANG GADIS PEMBERANI YAKNI TAMU SUBSCRIBER YANG MEMAKSA INGIN MENGIKUTI EXPLORASI MALAM DI MAKAM DEMI MEMBIAYAI KEBUTUHAN HIDUPNYA DAN ADIKNYA SEKOLAH NAMUN PADA SAAT EXPLORE KAMI DI CURIGAI OLEH WARGA SEKITAR SEHINGGA KAMI HAMPIR DI TUDUH YANG ANEH ANEH KARENA MEMBAWA SEORANG GADIS NAMUN SEMUA INI HANYA SEBUAH KESALAHPAHAMAN SAJA
#
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  GADISPEMBERANI  DEMIBIAYASEKOLAH  KAYAKO
# 2019-07-19 06:07:59+00:00
# 5
#      SUARA TANGISAN   PENGHUNI MAKAM
#  PADA SAAT SURVEI MAKAM HOST MENDENGAR SUARA TANGISAN POHON PENGHUNI MAKAM
#
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
#
# SILAHKAN COMMENT  JIKA KALIAN MENDENGAR HAL ANEH ATAUPUN MELIHAT SESUATU PADA SAAT EXPLORE DI SIANG HARI
#
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
#
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  SUARATANGISAN  PENUNGGUPOHON   PENGHUNIMAKAM
# 2019-07-18 17:13:12+00:00
# 4
#    SUARA GERAMAN MACAN   UJI NYALI
#  PADA SAAT UJI NYALI KALI INI BANYAK SEKALI SUARA SUARA ANEH SERTA DAHAN POHON BERGERAK DENGAN SENDIRINYA DAN TERMASUK GERAMAN MACAN
#
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  UJINYALI  SOSOKBAYANGANHITAM  GERAMANMACAN
# 2019-07-11 18:01:46+00:00
# 4
#      BANASPATI   SOSOK HANTU API
#  TERDAPAT SOSOK HANTU API ALIAS BANASPATI SETELAH MENDENGAR SUARA MISTERIUS TIBA TIBA BANASPATI TERSEBUT TERBANG DARI BALIK BANGUNAN REOT
#
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  BANASPATI  HANTUAPI  MAKAMANGKER
# 2019-07-11 01:01:43+00:00
# 4
#      SUARA GERAMAN   BARU ADA YANG DI KUBUR
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
#
# SILAHKAN COMMENT  JIKA KALIAN MENDENGAR HAL ANEH ATAUPUN MELIHAT SESUATU PADA SAAT EXPLORE DI SIANG HARI
#
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
#
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  SUARAMISTERIUS  MAKAMANGKER  KUNTILANAK
# 2019-07-12 17:34:31+00:00
# 5
#    POCONG NGAMUK   UJI NYALI
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  UJINYALI  SOSOKBAYANGANHITAM  POCONGNGAMUK
# 2019-07-09 16:58:00+00:00
# 2
#    RUMAH YANG BERISI KUBURAN KAKEK CANGKUL
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  RUMAHKAKEKCANGKUL  RUMAHISIKUBURAN  KAKEKCANGKUL
# 2019-07-05 15:04:02+00:00
# 5
#    RUMAH KAKEK CANGKUL DI KELILINGI MAKAM
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
#
# SILAHKAN COMMENT  JIKA KALIAN MENDENGAR HAL ANEH ATAUPUN MELIHAT SESUATU PADA SAAT EXPLORE DI SIANG HARI
#
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
#
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  SUARAMISTERIUS  MAKAMANGKER  KAKEKCANGKUL
# 2019-07-05 10:54:18+00:00
# 5
#      UJI NYALI   TANGISAN BAYI MINTA NENEN KUNTILANAK
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  UJINYALI  DISERANGKUNTLANAK  KUNTILANAKGENDONGBAYI
# 2019-07-02 11:16:05+00:00
# 2
#    PERHATIKAN BANASPATI DAN KUNTILANAK GENDONG BAYI MENGHILANG DI DEPAN MATA   PART
#  BELUM PUAS KAMI EXPLORE KEMARIN  KAMI EXPLORE KEMBALI DAN AKHIRNYA TEREKAM JELAS SOSOK BANASPATI DAN KUNTILANAK GENDONG BAYI MENGHILANG DI DEPAN MATA KAMI
#
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  BANASPATI  KUNTILANAK  KUNTILANAKMENGHILANGDIDEPANMATA
# 2019-07-01 15:11:24+00:00
# 1
#    PERHATIKAN     KUNTILANAK MENGGENDONG BAYI   PART
#  PADA SAAT EXPLORE KITA MENDENGAR SUARA TERIAKAN BAYI YANG MENAGIS DAN KEMUDIAN KITA MELIHAT SOSOK KUNTILANAK MUNGKIN KUNTILANAK TERSEBUT MENGGENDONG BAYI YANG MENANGIS TIBA TIBA HUJAN TURUN SEHINGGA KAMI TERJEBAK DI MAKAM
#
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  MAKAMANGKER  SUARAMISTERIUS  KUNTILANAKGENDONGBAYI
# 2019-06-28 11:54:40+00:00
# 5
#    DENGARKAN JERITAN     RUMOR KUNTILANAK GENDONG BAYI
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
#
# SILAHKAN COMMENT  JIKA KALIAN MENDENGAR HAL ANEH ATAUPUN MELIHAT SESUATU PADA SAAT EXPLORE DI SIANG HARI
#
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
#
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  SUARAMISTERIUS  RUMOR  KUNTILANAKGENDONGBAYI
# 2019-06-26 15:47:41+00:00
# 3
#      UJI NYALI   CAMERA ERROR   ULAH DEDEMIT BIKIN GAGAL MEREKAM
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  UJINYALI  POCONG  DEDEMIT
# 2019-06-25 18:09:16+00:00
# 2
#    JANGAN TONTON SENDIRIAN     ADA SOSOK MISTERIUS DI BALIK POHON
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  SUARAMISTERIUS  POCONGPEMALU  MAKAMANGKER
# 2019-06-25 16:58:47+00:00
# 2
#    ADUUUH    KEMBALI LAGI DI MAKAM YANG TERKENAL ANGKER
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
#
# SILAHKAN COMMENT  JIKA KALIAN MENDENGAR HAL ANEH ATAUPUN MELIHAT SESUATU PADA SAAT EXPLORE DI SIANG HARI
#
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
#
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  SURVEI  SUARAMISTERIUS  MAKAMANGKER
# 2019-06-23 01:05:26+00:00
# 0
#      UJI NYALI   TEREKAM SOSOK KUNTILANAK TERBANG KE ATAS POHON
# JANGAN LUPA YA TONTON SI ACENG JAGOAN
# DI CHANNEL GLOUD STUDIOS SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
# ...
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
#
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  PENAMPAKAN  POCONG  KUBURANANGKER
# 2019-01-10 07:29:11+00:00
# 4
#    TANTANGAN CIUM BATU NISAN KUBURAN ANGKER TENGAH MALAM
# CHANNEL BARU DARI KAMI SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
#
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
#
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  CIUMKUBURAN  CIUMBATUNISAN  KUBURANANGKER
# 2019-01-09 07:29:45+00:00
# 3
#      SEREM   JELAJAH KUBURAN CHINA DI SIANG BOLONG
# CHANNEL BARU DARI KAMI SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
#
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
#
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  KUBURANCHINA  HORROR  SERAM
# 2019-01-07 04:23:59+00:00
# 1
#    CAMERAMAN TERJATUH DI TARIK SETAN
# CHANNEL BARU DARI KAMI SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
#
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
#
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  SUARAMISTERIUS  HUTAN  INSIDEN
# 2019-01-07 04:09:00+00:00
# 1
#    RINTIHAN MISTERIUS DI HUTAN
# CHANNEL BARU DARI KAMI SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
#
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
#
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  SUARAMISTERIUS  RINTIHANMISTERIUS  HUTAN
# 2019-01-05 02:31:59+00:00
# 6
#    KUNTILANAK DATANG   AKIBAT BERSIUL DI MAKAM
# CHANNEL BARU DARI KAMI SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
#
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
#
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  KUNTILANAK  KUBURAN  SUARAMISTERIUS
# 2019-01-03 03:26:49+00:00
# 4
#      PAYAH   POCONGNYA MALU MALU KUCING
# CHANNEL BARU DARI KAMI SEBUAH SERIAL ACTION COMEDY YANG AKAN SELALU MENEMANI HARI LIBUR DAN MENGURANGI STRESS KARENA AKSI KOCAKNYA YANG BIKIN KALIAN NGAKAK 🤣🤣🤣
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UCYFEXIRGQAMY9YYSZINDW6Q
# —————————————————————————————————————
#
# HOST    HERRYROSHAN
# CAMERAMAN    IAMHADIWIBOWO
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#
# DALAM SEGALA KONDISI APAPUN LAZIMKAN MEMBACA DO A INI TERUTAMA KETIKA DALAM KEADAAN TAKUT
#
# مَا مِنْ عَبْدٍ يَقُولُ فِي صَبَاحِ كُلِّ يَوْمٍ وَمَسَاءِ كُلِّ لَيْلَةٍ
# بِسْمِ اللَّهِ الَّذِي لَا يَضُرُّ مَعَ اسْمِهِ شَيْءٌ فِي الْأَرْضِ وَلَا فِي السَّمَاءِ وَهُوَ السَّمِيعُ الْعَلِيمُ ثَلَاثَ مَرَّاتٍ لَمْ يَضُرَّهُ شَيْءٌ   قال الترمذي   حسن صحيح غريب   وصححه ابن القيم في   زاد المعاد      ، وصححه الألباني في   صحيح أبي داود
#
# “TIDAKLAH SEORANG HAMBA MEMBACA DI PAGI SETIAP HARI DAN SORE SETIAP MALAM”
#
# “DENGAN NAMA ALLAH YANG TIDAK ADA YANG DAPAT MENCELAKAI BERSAMA NAMA NYA APAPUN YANG ADA DI BUMI DAN DI LANGIT  DAN DIA MAHA MENDENGAR LAGI MAHA MELIHAT ”
#
#  TIGA KALI  MAKA TIDAK AKAN TERKENA BENCANA APAPUN ”
#
#
# PAKAI HEADSET
# MATIKAN LAMPU
# RASAKAN SENSASINYA
#
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
#
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
#  KUNTILANAK  POCONG  KUBURANANGKER
# 2018-12-31 07:48:09+00:00
# 1
# INTRO LORONG MISTERI
# MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS DI TEMPAT ANGKER DAN KERAMAT
# —————————————————————————————
# SOCIAL MEDIA
#
# INSTAGRAM  LORONGMISTERI   HTTPS   WWW INSTAGRAM COM LORONGMISTERI
#
# SUBSCRIBE HTTPS   WWW YOUTUBE COM CHANNEL UC0WGFW8UVW8YLPOSDZ 82DW
#
# PLAYLIST PENAMPAKAN TERHORROR
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFSKAYVWCBYZNDAGM7BWALG
#
# PLAYLIST PENAMPAKAN TERJELAS
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGN8V2JV28QJTAETY8JBU28
#
# PLAYLIST UJI NYALI
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FEHELIGKSISRQ7EC6VGGJNY
#
# PLAYLIST LORONG MISTER JALAN JALAN
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FFNJWJ86QIVFNE UIJMR2EW
#
# PLAYLIST SURVEI LOKASI TEMPAT ANGKER
# HTTPS   WWW YOUTUBE COM PLAYLIST LIST PLKU 6NQX49FGLQ51FQDYQ0ZWNOEBRXVIA
#      hari  ...                                               desc
# 0       3  ...  SUBSCRIBE AHD STUDIOS   HTTPS   WWW YOUTUBE CO...
# 1       2  ...  SUBSCRIBE AHD STUDIOS   HTTPS   WWW YOUTUBE CO...
# 2       1  ...  SUBSCRIBE AHD STUDIOS   HTTPS   WWW YOUTUBE CO...
# 3       0  ...  SUBSCRIBE AHD STUDIOS   HTTPS   WWW YOUTUBE CO...
# 4       6  ...  SUBSCRIBE AHD STUDIOS   HTTPS   WWW YOUTUBE CO...
# ..    ...  ...                                                ...
# 809     1  ...  CHANNEL BARU DARI KAMI SEBUAH SERIAL ACTION CO...
# 810     1  ...  CHANNEL BARU DARI KAMI SEBUAH SERIAL ACTION CO...
# 811     6  ...  CHANNEL BARU DARI KAMI SEBUAH SERIAL ACTION CO...
# 812     4  ...  CHANNEL BARU DARI KAMI SEBUAH SERIAL ACTION CO...
# 813     1  ...  MENYINGKAP FAKTA TENTANG RUMOR BERBAU MISTIS D...
#
# [814 rows x 6 columns]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [('UJI', 315), ('NYALI', 315), ('DI', 268), ('KUNTILANAK', 220), ('LIVE', 91), ('BANG', 88), ('SOSOK', 75), ('KISAH', 55), ('ANGKER', 50), ('PODCAST', 48)]
#       jam  jami  judul  durasi  desc
# hari
# 0      80    80     80      80    80
# 1     123   123    123     123   123
# 2     129   129    129     129   129
# 3     129   129    129     129   129
# 4     114   114    114     114   114
# 5     130   130    130     130   130
# 6     109   109    109     109   109
#      hari  jami  judul  durasi  desc
# jam
# 00     10    10     10      10    10
# 01      9     9      9       9     9
# 02     20    20     20      20    20
# 03     24    24     24      24    24
# 04     22    22     22      22    22
# 05     34    34     34      34    34
# 06     29    29     29      29    29
# 07     50    50     50      50    50
# 08     34    34     34      34    34
# 09     58    58     58      58    58
# 10     74    74     74      74    74
# 11     69    69     69      69    69
# 12     78    78     78      78    78
# 13     98    98     98      98    98
# 14     45    45     45      45    45
# 15     48    48     48      48    48
# 16     32    32     32      32    32
# 17     21    21     21      21    21
# 18     17    17     17      17    17
# 19      9     9      9       9     9
# 20      5     5      5       5     5
# 21      4     4      4       4     4
# 22     11    11     11      11    11
# 23     13    13     13      13    13
#       jam  jami  judul  durasi  desc
# hari
# 0      80    80     80      80    80
# 1     123   123    123     123   123
# 2     129   129    129     129   129
# 3     129   129    129     129   129
# 4     114   114    114     114   114
# 5     130   130    130     130   130
# 6     109   109    109     109   109
#       hari  jam  judul  durasi  desc
# jami
# 1      198  198    198     198   198
# 3      616  616    616     616   616
# 0 days 00:23:29.809582309
